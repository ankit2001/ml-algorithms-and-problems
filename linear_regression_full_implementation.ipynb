# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(19.0,16.0)

# %%
data=pd.read_csv('/home/ankittt2001/Desktop/ml algorithms and problems/datasetse/train.csv')
data.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
X=data.iloc[:,0]
Y=data.iloc[:,1]
plt.scatter(X,Y)
plt.show()
data.head()
m= 0
c = 0

L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(Y)) # Number of elements in X
sumi=0.0
for i in range(len(Y)):
    sumi =sumi+Y[i]
print(sumi)    
# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    #D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
   # D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
   # m = m - L * D_m  # Update m
    #c = c - L * D_c  # Update c
# Out:
# nan

# %%
q1=5
q2=3
alpha=0.001
n=float(len(X))
print(len(Y))
for i in range(100):
    Y_obs=q1*X+q2
    diff1=(-2/n)*sum(Y-Y_obs)
    print(diff1)
    diff2=(-2/n)*add((Y-Y_obs)*X)
    q1=q1-diff2*alpha
    q2=q2-diff1*alpha
# Out:
# 700
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-db9a0687813b> in <module>
#       6 for i in range(100):
#       7     Y_obs=q1*X+q2
# ----> 8     diff1=(-2/n)*sum(Y-Y_obs)
#       9     print(diff1)
#      10     diff2=(-2/n)*add((Y-Y_obs)*X)
#
# TypeError: 'int' object is not callable

# %%
Y_pred=q1*X+q2
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(Y_pred),max(Y_pred)], color="red")
plt.show()
